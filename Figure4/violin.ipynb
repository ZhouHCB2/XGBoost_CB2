# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('reg.csv')
type=df['source']
PActivity=df['PActivity']

# %%
plt.style.use('ggplot')
sns.violinplot(x=type,
               y=df.PActivity)
plt.savefig('reg.jpg')
plt.show()

# %%
df = pd.read_csv('ml_class_3path_xgb_violine.csv')
type=df1['type']
test_ROC=df1['test_AUC_ROC']

# %%
plt.style.use('ggplot')
sns.violinplot(x=type,
               y=test_ROC)
plt.savefig('RF.jpg')
plt.show()

# %%
df1 = pd.read_csv('ml_class_3path_rf_violine.csv')
type=df1['type']
test_ROC=df1['test_AUC_ROC']

# %%
plt.style.use('ggplot')
sns.violinplot(x=type,
               y=test_ROC)
plt.savefig('RF.jpg')
plt.show()

# %%
df2 = pd.read_csv('ml_class_3path_knn_violine.csv')
type=df2['type']
test_ROC=df2['test_ROC']

# %%
plt.style.use('ggplot')
sns.violinplot(x=type,
               y=test_ROC)
plt.savefig('KNN.jpg')
plt.show()

# %%
df1 = pd.read_csv('BdbReg1344.csv')
CB2_BDB_R = df1['PActivity']

# %%
df2 = pd.read_csv('ChblReg6227.csv')
CB2_Chembl_R = df2['PActivity']

# %%
df3 = pd.read_csv('ijms2616.csv')
Mizera = df3['PActivity']

# %%
data={'CB2_Chembl_R': CB2_Chembl_R,'CB2_BDB_R':CB2_BDB_R,'Mizera':Mizera}

# %%
df = pd.DataFrame(data)

# %%
df.plot.box()
plt.grid(linestyle="--",alpha=0.3)
plt.show()
plt.savefig('a.jpg')
# Out:
# D:\Program\Anaconda3\Lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
